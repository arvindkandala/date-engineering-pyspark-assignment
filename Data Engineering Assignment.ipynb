# %%
dbutils.fs.ls("/databricks-datasets/")
# Out:
# [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1596557781000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1596557823000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/bikeSharing/', name='bikeSharing/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/cctvVideos/', name='cctvVideos/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/', name='credit-card-fraud/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/cs100/', name='cs100/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/cs110x/', name='cs110x/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/cs190/', name='cs190/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/data.gov/', name='data.gov/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/definitive-guide/', name='definitive-guide/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/delta-sharing/', name='delta-sharing/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/flights/', name='flights/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/flower_photos/', name='flower_photos/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/flowers/', name='flowers/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/genomics/', name='genomics/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/hail/', name='hail/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/identifying-campaign-effectiveness/', name='identifying-campaign-effectiveness/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/iot/', name='iot/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/iot-stream/', name='iot-stream/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark/', name='learning-spark/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark-v2/', name='learning-spark-v2/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/lending-club-loan-stats/', name='lending-club-loan-stats/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/med-images/', name='med-images/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/media/', name='media/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/mnist-digits/', name='mnist-digits/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/news20.binary/', name='news20.binary/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/', name='nyctaxi/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi-with-zipcodes/', name='nyctaxi-with-zipcodes/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/online_retail/', name='online_retail/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/overlap-join/', name='overlap-join/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/power-plant/', name='power-plant/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/', name='retail-org/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/rwe/', name='rwe/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/sai-summit-2019-sf/', name='sai-summit-2019-sf/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/sample_logs/', name='sample_logs/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/samples/', name='samples/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/sfo_customer_survey/', name='sfo_customer_survey/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/sms_spam_collection/', name='sms_spam_collection/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/songs/', name='songs/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/structured-streaming/', name='structured-streaming/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/timeseries/', name='timeseries/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/tpch/', name='tpch/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/travel_recommendations_realtime/', name='travel_recommendations_realtime/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/warmup/', name='warmup/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/weather/', name='weather/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/wiki/', name='wiki/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/wikipedia-datasets/', name='wikipedia-datasets/', size=0, modificationTime=1762892681493),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/', name='wine-quality/', size=0, modificationTime=1762892681493)]

# %%
import pandas as pd
import time
from pyspark.sql.functions import col, count, avg, sum as spark_sum, desc, when
from pyspark.sql import functions as F
# Verify Spark is ready (spark is pre-created in Databricks)
print(f"✅ Spark version: {spark.version}")
print(f"✅ Ready to go!")
# Out:
# ✅ Spark version: 4.0.0
# ✅ Ready to go!

# %%
dbutils.fs.ls("/databricks-datasets/wine-quality/")
# Out:
# [FileInfo(path='dbfs:/databricks-datasets/wine-quality/README.md', name='README.md', size=1066, modificationTime=1596692263000),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/winequality-red.csv', name='winequality-red.csv', size=84199, modificationTime=1596692263000),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/winequality-white.csv', name='winequality-white.csv', size=264426, modificationTime=1596692263000)]

# %%
path = "/databricks-datasets/wine-quality/winequality-white.csv"

info = dbutils.fs.ls(path)[0]
size_bytes = info.size
size_gb_single = size_bytes / (1024**3)

dup_factor = 5000  # how many times you union it
size_gb_large = size_gb_single * dup_factor

print("Single file size (GB):", size_gb_single)
print("Estimated df_large size (GB):", size_gb_large)
# Out:
# Single file size (GB): 0.0002462659031152725
# Estimated df_large size (GB): 1.2313295155763626

# %%
# White wine
df_base_white = (
    spark.read.format("csv")
        .option("header", "true")
        .option("sep", ";")
        .option("inferSchema", "true")
        .load("/databricks-datasets/wine-quality/winequality-white.csv")
        .withColumn("wine_type", F.lit("white"))  # tag source
)

# Red wine
df_base_red = (
    spark.read.format("csv")
        .option("header", "true")
        .option("sep", ";")
        .option("inferSchema", "true")
        .load("/databricks-datasets/wine-quality/winequality-red.csv")
        .withColumn("wine_type", F.lit("red"))
)


df_base = df_base_white.unionByName(df_base_red)

# %%
# How many times to replicate the full base dataset
repeat_factor = 4000  # How many times to replicate the full base dataset

multiplier = spark.range(repeat_factor).toDF("rep_id")

df_large = (
    df_base
        .crossJoin(multiplier)   # replicates each row repeat_factor times
        .drop("rep_id")          # no longer needed
)

print(df_large.count())
# Out:
# 25988000

# %%
df_filtered = (
    df_large
        .filter(
            F.col("quality").isNotNull() &
            F.col("alcohol").isNotNull() &
            F.col("residual sugar").isNotNull()
        )
        # want decent quality
        .filter(F.col("quality") >= 5)
        # avoid extreme outliers in volatile acidity
        .filter(F.col("volatile acidity") < 1.5)
)

# %%
df_transformed = (
    df_filtered
        # binary label for high quality
        .withColumn("is_high_quality", (F.col("quality") >= 7).cast("int"))
        # alc to sugar ratio
        .withColumn(
            "alcohol_sugar_ratio",
            F.col("alcohol") / (F.col("residual sugar") + F.lit(1e-6))
        )
)

# %%
#groupBy aggregation
quality_summary = (
    df_transformed
        .groupBy("wine_type", "quality")
        .agg(
            F.count("*").alias("num_wines"),
            F.round(F.avg("alcohol"), 3).alias("avg_alcohol"),
            F.round(F.avg("residual sugar"), 3).alias("avg_residual_sugar"),
            F.round(F.avg("alcohol_sugar_ratio"), 3).alias("avg_alcohol_sugar_ratio"),
            F.round(F.avg("is_high_quality") * 100, 2).alias("pct_high_quality")
        )
        .orderBy("wine_type", "quality")
)

quality_summary.show(20, truncate=False)
# Out:
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+
# |wine_type|quality|num_wines|avg_alcohol|avg_residual_sugar|avg_alcohol_sugar_ratio|pct_high_quality|
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+
# |red      |5      |2724000  |9.9        |2.529             |4.449                  |0.0             |
# |red      |6      |2552000  |10.63      |2.477             |4.86                   |0.0             |
# |red      |7      |796000   |11.466     |2.721             |4.895                  |100.0           |
# |red      |8      |72000    |12.094     |2.578             |5.415                  |100.0           |
# |white    |5      |5828000  |9.809      |7.335             |3.204                  |0.0             |
# |white    |6      |8792000  |10.575     |6.442             |3.687                  |0.0             |
# |white    |7      |3520000  |11.368     |5.186             |4.241                  |100.0           |
# |white    |8      |700000   |11.636     |5.671             |3.914                  |100.0           |
# |white    |9      |20000    |12.18      |4.12              |4.774                  |100.0           |
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+

# %%
#join operation

white_stats = (
    df_transformed
        .filter(F.col("wine_type") == "white")
        .groupBy("quality")
        .agg(
            F.round(F.avg("alcohol"), 3).alias("white_avg_alcohol"),
            F.count("*").alias("white_count")
        )
)

red_stats = (
    df_transformed
        .filter(F.col("wine_type") == "red")
        .groupBy("quality")
        .agg(
            F.round(F.avg("alcohol"), 3).alias("red_avg_alcohol"),
            F.count("*").alias("red_count")
        )
)

quality_compare = (
    white_stats
        .join(red_stats, on="quality", how="inner")
        .orderBy("quality")
)

quality_compare.show(truncate=False)
# Out:
# +-------+-----------------+-----------+---------------+---------+
# |quality|white_avg_alcohol|white_count|red_avg_alcohol|red_count|
# +-------+-----------------+-----------+---------------+---------+
# |5      |9.809            |5828000    |9.9            |2724000  |
# |6      |10.575           |8792000    |10.63          |2552000  |
# |7      |11.368           |3520000    |11.466         |796000   |
# |8      |11.636           |700000     |12.094         |72000    |
# +-------+-----------------+-----------+---------------+---------+

# %%
df_transformed.createOrReplaceTempView("wine_large")

# %%
sql_summary_by_type = spark.sql("""
SELECT
    wine_type,
    COUNT(*)                         AS num_rows,
    AVG(quality)                     AS avg_quality,
    AVG(alcohol)                     AS avg_alcohol,
    AVG(is_high_quality) * 100       AS pct_high_quality
FROM wine_large
GROUP BY wine_type
ORDER BY avg_quality DESC
""")

sql_summary_by_type.show()
# Out:
# +---------+--------+------------------+------------------+------------------+
# |wine_type|num_rows|       avg_quality|       avg_alcohol|  pct_high_quality|
# +---------+--------+------------------+------------------+------------------+
# |    white|18860000|5.9550371155885475|10.527493107104402|22.481442205726403|
# |      red| 6144000| 5.709635416666667|10.431477864583332|14.127604166666666|
# +---------+--------+------------------+------------------+------------------+

# %%
sql_high_segment = spark.sql("""
SELECT
    wine_type,
    quality,
    COUNT(*)              AS num_wines,
    AVG(alcohol)          AS avg_alcohol,
    AVG(`residual sugar`) AS avg_residual_sugar
FROM wine_large
WHERE
    quality >= 7
    AND alcohol >= 11
GROUP BY wine_type, quality
ORDER BY quality DESC, wine_type
""")

sql_high_segment.show()
# Out:
# +---------+-------+---------+------------------+------------------+
# |wine_type|quality|num_wines|       avg_alcohol|avg_residual_sugar|
# +---------+-------+---------+------------------+------------------+
# |    white|      9|    16000|12.624999999999998|               2.5|
# |      red|      8|    64000|12.368750000000889|           2.65625|
# |    white|      8|   540000|12.209629629628767| 4.697777777777816|
# |      red|      7|   552000|11.961352657005365|2.7398550724638926|
# |    white|      7|  2308000|  12.0947429231664| 3.985441941074224|
# +---------+-------+---------+------------------+------------------+

# %%
#partitioning
import time

start = time.time()
baseline = (
    df_transformed
        .groupBy("wine_type")
        .agg(F.count("*").alias("num_wines"))
        .collect()
)
baseline_time = time.time() - start
print(f"Default partitions: {baseline_time:.2f}s")

df_few = df_transformed.repartition(4)
start = time.time()
few = (
    df_few
        .groupBy("wine_type")
        .agg(F.count("*").alias("num_wines"))
        .collect()
)
few_time = time.time() - start
print(f"4 partitions:     {few_time:.2f}s")

df_many = df_transformed.repartition(32)
start = time.time()
many = (
    df_many
        .groupBy("wine_type")
        .agg(F.count("*").alias("num_wines"))
        .collect()
)
many_time = time.time() - start
print(f"32 partitions:     {many_time:.2f}s")
# Out:
# Default partitions: 0.42s
# 4 partitions:     1.38s
# 32 partitions:     1.47s

# %%
#since it is slower with partitioning (likely due to the overhead cost of it), I will not use partitioning
df_transformed.createOrReplaceTempView("wine_large")

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS student_db")

quality_summary.write.mode("overwrite").saveAsTable("student_db.wine_quality_summary")

print("Saved table: student_db.wine_quality_summary")

display(spark.table("student_db.wine_quality_summary").limit(10))
# Out:
# Saved table: student_db.wine_quality_summary
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>wine_type</th><th>quality</th><th>num_wines</th><th>avg_alcohol</th><th>avg_residual_sugar</th><th>avg_alcohol_sugar_ratio</th><th>pct_high_quality</th></tr></thead><tbody><tr><td>red</td><td>5</td><td>2724000</td><td>9.9</td><td>2.529</td><td>4.449</td><td>0.0</td></tr><tr><td>red</td><td>6</td><td>2552000</td><td>10.63</td><td>2.477</td><td>4.86</td><td>0.0</td></tr><tr><td>red</td><td>7</td><td>796000</td><td>11.466</td><td>2.721</td><td>4.895</td><td>100.0</td></tr><tr><td>red</td><td>8</td><td>72000</td><td>12.094</td><td>2.578</td><td>5.415</td><td>100.0</td></tr><tr><td>white</td><td>5</td><td>5828000</td><td>9.809</td><td>7.335</td><td>3.204</td><td>0.0</td></tr><tr><td>white</td><td>6</td><td>8792000</td><td>10.575</td><td>6.442</td><td>3.687</td><td>0.0</td></tr><tr><td>white</td><td>7</td><td>3520000</td><td>11.368</td><td>5.186</td><td>4.241</td><td>100.0</td></tr><tr><td>white</td><td>8</td><td>700000</td><td>11.636</td><td>5.671</td><td>3.914</td><td>100.0</td></tr><tr><td>white</td><td>9</td><td>20000</td><td>12.18</td><td>4.12</td><td>4.774</td><td>100.0</td></tr></tbody></table></div>

# %%
quality_compare.write.mode("overwrite").saveAsTable("student_db.wine_quality_compare")

print("Saved table: student_db.wine_quality_compare")

display(spark.table("student_db.wine_quality_compare").limit(10))
# Out:
# Saved table: student_db.wine_quality_compare
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>quality</th><th>white_avg_alcohol</th><th>white_count</th><th>red_avg_alcohol</th><th>red_count</th></tr></thead><tbody><tr><td>5</td><td>9.809</td><td>5828000</td><td>9.9</td><td>2724000</td></tr><tr><td>6</td><td>10.575</td><td>8792000</td><td>10.63</td><td>2552000</td></tr><tr><td>7</td><td>11.368</td><td>3520000</td><td>11.466</td><td>796000</td></tr><tr><td>8</td><td>11.636</td><td>700000</td><td>12.094</td><td>72000</td></tr></tbody></table></div>

# %%
quality_summary.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (29)
# +- == Initial Plan ==
#    ColumnarToRow (28)
#    +- PhotonResultStage (27)
#       +- PhotonSort (26)
#          +- PhotonShuffleExchangeSource (25)
#             +- PhotonShuffleMapStage (24)
#                +- PhotonShuffleExchangeSink (23)
#                   +- PhotonProject (22)
#                      +- PhotonGroupingAgg (21)
#                         +- PhotonShuffleExchangeSource (20)
#                            +- PhotonShuffleMapStage (19)
#                               +- PhotonShuffleExchangeSink (18)
#                                  +- PhotonGroupingAgg (17)
#                                     +- PhotonBroadcastNestedLoopJoin Cross BuildRight (16)
#                                        :- PhotonGroupingAgg (10)
#                                        :  +- PhotonUnion (9)
#                                        :     :- PhotonProject (4)
#                                        :     :  +- PhotonFilter (3)
#                                        :     :     +- PhotonRowToColumnar (2)
#                                        :     :        +- Scan csv  (1)
#                                        :     +- PhotonProject (8)
#                                        :        +- PhotonFilter (7)
#                                        :           +- PhotonRowToColumnar (6)
#                                        :              +- Scan csv  (5)
#                                        +- PhotonShuffleExchangeSource (15)
#                                           +- PhotonShuffleMapStage (14)
#                                              +- PhotonShuffleExchangeSink (13)
#                                                 +- PhotonProject (12)
#                                                    +- PhotonRange (11)
#
#
# (1) Scan csv
# Output [4]: [volatile acidity#12163, residual sugar#12165, alcohol#12172, quality#12173]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/wine-quality/winequality-white.csv]
# PushedFilters: [IsNotNull(quality), IsNotNull(volatile acidity), IsNotNull(alcohol), IsNotNull(residual sugar), GreaterThanOrEqual(quality,5), LessThan(volatile acidity,1.5)]
# ReadSchema: struct<volatile acidity:double,residual sugar:double,alcohol:double,quality:int>
#
# (2) PhotonRowToColumnar
# Input [4]: [volatile acidity#12163, residual sugar#12165, alcohol#12172, quality#12173]
#
# (3) PhotonFilter
# Input [4]: [volatile acidity#12163, residual sugar#12165, alcohol#12172, quality#12173]
# Arguments: (((((isnotnull(quality#12173) AND isnotnull(volatile acidity#12163)) AND isnotnull(alcohol#12172)) AND isnotnull(residual sugar#12165)) AND (quality#12173 >= 5)) AND (volatile acidity#12163 < 1.5))
#
# (4) PhotonProject
# Input [4]: [volatile acidity#12163, residual sugar#12165, alcohol#12172, quality#12173]
# Arguments: [residual sugar#12165, alcohol#12172, quality#12173, white AS wine_type#12176]
#
# (5) Scan csv
# Output [4]: [volatile acidity#12196, residual sugar#12198, alcohol#12205, quality#12206]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/wine-quality/winequality-red.csv]
# PushedFilters: [IsNotNull(quality), IsNotNull(volatile acidity), IsNotNull(alcohol), IsNotNull(residual sugar), GreaterThanOrEqual(quality,5), LessThan(volatile acidity,1.5)]
# ReadSchema: struct<volatile acidity:double,residual sugar:double,alcohol:double,quality:int>
#
# (6) PhotonRowToColumnar
# Input [4]: [volatile acidity#12196, residual sugar#12198, alcohol#12205, quality#12206]
#
# (7) PhotonFilter
# Input [4]: [volatile acidity#12196, residual sugar#12198, alcohol#12205, quality#12206]
# Arguments: (((((isnotnull(quality#12206) AND isnotnull(volatile acidity#12196)) AND isnotnull(alcohol#12205)) AND isnotnull(residual sugar#12198)) AND (quality#12206 >= 5)) AND (volatile acidity#12196 < 1.5))
#
# (8) PhotonProject
# Input [4]: [volatile acidity#12196, residual sugar#12198, alcohol#12205, quality#12206]
# Arguments: [residual sugar#12198, alcohol#12205, quality#12206, red AS wine_type#12209]
#
# (9) PhotonUnion
# Arguments: Generic
#
# (10) PhotonGroupingAgg
# Input [4]: [residual sugar#12165, alcohol#12172, quality#12173, wine_type#12176]
# Arguments: [wine_type#12176, quality#12173], [partial_count(1) AS count#15052L, partial_avg(alcohol#12172) AS (sum#15055, count#15056L), partial_avg(residual sugar#12165) AS (sum#15059, count#15060L), partial_avg((alcohol#12172 / (residual sugar#12165 + 1.0E-6))) AS (sum#15063, count#15064L), partial_avg(cast((quality#12173 >= 7) as int)) AS (sum#15067, count#15068L)], [count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L], [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L], false
#
# (11) PhotonRange
# Output [1]: [id#12219L]
# Arguments: Range (0, 4000, step=1, splits=8)
#
# (12) PhotonProject
# Input [1]: [id#12219L]
#
# (13) PhotonShuffleExchangeSink
# Input: []
# Arguments: SinglePartition
#
# (14) PhotonShuffleMapStage
# Input: []
# Arguments: EXECUTOR_BROADCAST, [id=#27143]
#
# (15) PhotonShuffleExchangeSource
# Input: []
#
# (16) PhotonBroadcastNestedLoopJoin
# Join type: Cross
# Join condition: None
#
# (17) PhotonGroupingAgg
# Input [11]: [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L]
# Arguments: [wine_type#12176, quality#12173], [merge_count(merge count#15052L) AS count#15052L, merge_avg(merge sum#15055, count#15056L) AS (sum#15055, count#15056L), merge_avg(merge sum#15059, count#15060L) AS (sum#15059, count#15060L), merge_avg(merge sum#15063, count#15064L) AS (sum#15063, count#15064L), merge_avg(merge sum#15067, count#15068L) AS (sum#15067, count#15068L)], [count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L], [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L], false
#
# (18) PhotonShuffleExchangeSink
# Input [11]: [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L]
# Arguments: hashpartitioning(wine_type#12176, quality#12173, 1024)
#
# (19) PhotonShuffleMapStage
# Input [11]: [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L]
# Arguments: ENSURE_REQUIREMENTS, [id=#27150]
#
# (20) PhotonShuffleExchangeSource
# Input [11]: [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L]
#
# (21) PhotonGroupingAgg
# Input [11]: [wine_type#12176, quality#12173, count#15052L, sum#15055, count#15056L, sum#15059, count#15060L, sum#15063, count#15064L, sum#15067, count#15068L]
# Arguments: [wine_type#12176, quality#12173], [finalmerge_count(merge count#15052L) AS count(1)#15046L, finalmerge_avg(merge sum#15055, count#15056L) AS avg(alcohol)#15047, finalmerge_avg(merge sum#15059, count#15060L) AS avg(residual sugar)#15048, finalmerge_avg(merge sum#15063, count#15064L) AS avg(alcohol_sugar_ratio)#15049, finalmerge_avg(merge sum#15067, count#15068L) AS avg(is_high_quality)#15050], [count(1)#15046L, avg(alcohol)#15047, avg(residual sugar)#15048, avg(alcohol_sugar_ratio)#15049, avg(is_high_quality)#15050], [wine_type#12176, quality#12173, count(1)#15046L, avg(alcohol)#15047, avg(residual sugar)#15048, avg(alcohol_sugar_ratio)#15049, avg(is_high_quality)#15050], true
#
# (22) PhotonProject
# Input [7]: [wine_type#12176, quality#12173, count(1)#15046L, avg(alcohol)#15047, avg(residual sugar)#15048, avg(alcohol_sugar_ratio)#15049, avg(is_high_quality)#15050]
# Arguments: [wine_type#12176, quality#12173, count(1)#15046L AS num_wines#15041L, round(avg(alcohol)#15047, 3) AS avg_alcohol#15042, round(avg(residual sugar)#15048, 3) AS avg_residual_sugar#15043, round(avg(alcohol_sugar_ratio)#15049, 3) AS avg_alcohol_sugar_ratio#15044, round((avg(is_high_quality)#15050 * 100.0), 2) AS pct_high_quality#15045]
#
# (23) PhotonShuffleExchangeSink
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
# Arguments: rangepartitioning(wine_type#12176 ASC NULLS FIRST, quality#12173 ASC NULLS FIRST, 1024)
#
# (24) PhotonShuffleMapStage
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
# Arguments: ENSURE_REQUIREMENTS, [id=#27158]
#
# (25) PhotonShuffleExchangeSource
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
#
# (26) PhotonSort
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
# Arguments: [wine_type#12176 ASC NULLS FIRST, quality#12173 ASC NULLS FIRST]
#
# (27) PhotonResultStage
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
#
# (28) ColumnarToRow
# Input [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
#
# (29) AdaptiveSparkPlan
# Output [7]: [wine_type#12176, quality#12173, num_wines#15041L, avg_alcohol#15042, avg_residual_sugar#15043, avg_alcohol_sugar_ratio#15044, pct_high_quality#15045]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
quality_summary.show()
# Out:
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+
# |wine_type|quality|num_wines|avg_alcohol|avg_residual_sugar|avg_alcohol_sugar_ratio|pct_high_quality|
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+
# |      red|      5|  2724000|        9.9|             2.529|                  4.449|             0.0|
# |      red|      6|  2552000|      10.63|             2.477|                   4.86|             0.0|
# |      red|      7|   796000|     11.466|             2.721|                  4.895|           100.0|
# |      red|      8|    72000|     12.094|             2.578|                  5.415|           100.0|
# |    white|      5|  5828000|      9.809|             7.335|                  3.204|             0.0|
# |    white|      6|  8792000|     10.575|             6.442|                  3.687|             0.0|
# |    white|      7|  3520000|     11.368|             5.186|                  4.241|           100.0|
# |    white|      8|   700000|     11.636|             5.671|                  3.914|           100.0|
# |    white|      9|    20000|      12.18|              4.12|                  4.774|           100.0|
# +---------+-------+---------+-----------+------------------+-----------------------+----------------+

# %%
sql_high_segment.show()
# Out:
# +---------+-------+---------+------------------+------------------+
# |wine_type|quality|num_wines|       avg_alcohol|avg_residual_sugar|
# +---------+-------+---------+------------------+------------------+
# |    white|      9|    16000|12.624999999999998|               2.5|
# |      red|      8|    64000|12.368750000000889|           2.65625|
# |    white|      8|   540000|12.209629629628767| 4.697777777777816|
# |      red|      7|   552000|11.961352657005365|2.7398550724638926|
# |    white|      7|  2308000|  12.0947429231664| 3.985441941074224|
# +---------+-------+---------+------------------+------------------+

# %%
#lazy
print("Step 1: Define a few transformations on df_transformed...\n")

demo_df = (
    df_transformed
        .filter(F.col("quality") >= 7)         # transformation 1 (lazy)
        .withColumn("quality_plus_one", F.col("quality") + 1)  # transformation 2 (lazy)
        .select("wine_type", "quality", "quality_plus_one")    # transformation 3 (lazy)
)

print("transformations defined")
print("no data has been fetched or computed yet (lazy)")
print("you won't see any spark job in the UI for this cell.\n")
# Out:
# Step 1: Define a few transformations on df_transformed...
#
# Transformations defined.
# No data has been fetched or computed yet (lazy).
# You won't see any Spark job in the UI for this cell.

# %%
#actions
print("Step 2: Trigger actions on the transformed DataFrame...\n")

print("Action 1: show()")
demo_df.show(5)

print("\nAction 2: count()")
print("Row count:", demo_df.count())
# Out:
# Step 2: Trigger actions on the transformed DataFrame...
#
# Action 1: show()
# +---------+-------+----------------+
# |wine_type|quality|quality_plus_one|
# +---------+-------+----------------+
# |    white|      7|               8|
# |    white|      7|               8|
# |    white|      8|               9|
# |    white|      8|               9|
# |    white|      7|               8|
# +---------+-------+----------------+
# only showing top 5 rows
#
# Action 2: count()
# Row count: 5108000
